# %%
import sys
sys.path.append('/home/ddutt/work/')
from suzieq.firecli.ospf import OspfObj

# %%
ospf = OspfObj()

# %%
df = ospf.get(namespace='ospf')

# %%
df.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_427e1c84_6c38_11e9_8492_f82819e2b473" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >namespace</th>
#         <th class="col_heading level0 col1" >hostname</th>
#         <th class="col_heading level0 col2" >vrf</th>
#         <th class="col_heading level0 col3" >ifname</th>
#         <th class="col_heading level0 col4" >state</th>
#         <th class="col_heading level0 col5" >peerIP</th>
#         <th class="col_heading level0 col6" >lastChangeTime</th>
#         <th class="col_heading level0 col7" >numChanges</th>
#         <th class="col_heading level0 col8" >timestamp</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_427e1c84_6c38_11e9_8492_f82819e2b473level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_427e1c84_6c38_11e9_8492_f82819e2b473row0_col0" class="data row0 col0" >ospf</td>
# ...
